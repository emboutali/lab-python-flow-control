# %% [markdown]
# # Lab | Flow Control

# %% [markdown]
# ## Exercise: Managing Customer Orders Optimized
#
# In the last lab, you were starting an online store that sells various products. To ensure smooth operations, you developed a program that manages customer orders and inventory.
#
# You did so without using flow control. Let's go a step further and improve this code.
#
# Follow the steps below to complete the exercise:
#
# 1. Look at your code from the lab data structures, and improve repeated code with loops.
#
# 2. Instead of asking the user to input the name of three products that a customer wants to order, do the following:
#
#     a. Prompt the user to enter the name of a product that a customer wants to order.
#
#     b. Add the product name to the "customer_orders" set.
#
#     c. Ask the user if they want to add another product (yes/no).
#
#     d. Continue the loop until the user does not want to add another product.
#
# 3. Instead of updating the inventory by subtracting 1 from the quantity of each product, only do it for  the products that were ordered (those in "customer_orders").

# %%
# ==========================================
# Step 1: List of available products
# ==========================================
products = ["t-shirt", "mug", "hat", "book", "keychain"]


# ==========================================
# Create an empty dictionary for the inventory
# ==========================================
inventory = {}

# ==========================================
# Ask for the quantity of each product
# ==========================================
for product in products:
    quantity = input("Enter the quantity of " + product + "s available: ")
    quantity = int(quantity)  # convert the text into a whole number
    inventory[product] = quantity

# ==========================================
# Create an empty set for customer orders
# ==========================================
customer_orders = set()

# ==========================================
# Step 2: Ask for products one at a time
# ==========================================
keep_asking = True  # variable that controls whether we keep asking

while keep_asking == True:
    order = input("Enter the name of a product that a customer wants to order: ")
    customer_orders.add(order)

    answer = input("Do you want to add another product? (yes/no): ")

    if answer == "no":
        keep_asking = False  # stop the loop

# ==========================================
# Print the ordered products
# ==========================================
print("")
print("Products in customer_orders:", customer_orders)

# ==========================================
# Calculate the order statistics
# ==========================================
total_products_ordered = len(customer_orders)
percentage_ordered = (total_products_ordered / len(products)) * 100

order_status = (total_products_ordered, percentage_ordered)

print("")
print("Order Statistics:")
print("Total Products Ordered:", order_status[0])
print("Percentage of Products Ordered:", order_status[1], "%")

# ==========================================
# Step 3: Update the inventory
# ==========================================
for product in customer_orders:
    inventory[product] = inventory[product] - 1

# ==========================================
# Print the final inventory
# ==========================================
print("")
print("Updated Inventory:")
for product in inventory:
    print(product, ":", inventory[product])
# Out:
# Products in customer_orders: {'hqt'}
#
# Order Statistics:
# Total Products Ordered: 1
# Percentage of Products Ordered: 20.0 %
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[1], line 62
#      58 # ==========================================
#      59 # Step 3: Update the inventory
#      60 # ==========================================
#      61 for product in customer_orders:
# ---> 62     inventory[product] = inventory[product] - 1
#      63
#      64 # ==========================================
#      65 # Print the final inventory
#
# KeyError: 'hqt'
